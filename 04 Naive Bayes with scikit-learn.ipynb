# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer # vocabulary generation
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import recall_score, precision_score, f1_score

# %%
DATA_JSON_FILE = 'C:/github/SpamData/01_Processing/email-text-data.json'

# %%
data = pd.read_json(DATA_JSON_FILE)
data.tail()
# Out:
#      CATEGORY                                            MESSAGE  \
# 995         1  This is a multi-part message in MIME format.\n...
# 996         1  PROMOTE YOUR PRODUCT OR SERVICE TO MILLIONS TO...
# 997         1  <html>\n\n<head>\n\n</head>\n\n<body>\n\n\n\n<...
# 998         1  As to\n\n\n\n\n\n\n\nWant to refinance?\n\n\n\...
# 999         1  Dear Sirs,\n\nWe know your esteemed company in...
#
#                                   FILE_NAME
# 995  00497.353a61b265f11dd0bae116c0149abbe1
# 996  00498.7f293b818e2e46d3a8bad44eda672947
# 997  00499.257302b8f6056eb85e0daa37bfcd2c68
# 998  00500.87320162ab5b79f67978406cf909c3d1
# 999  00501.32679091b0520132ad888ef3b134ce48

# %%
data.shape # not in index order
# Out:
# (5847, 3)

# %%
data.sort_index(inplace=True) # sort according to index

# %%
data.tail() # last five rows
# Out:
#       CATEGORY                                            MESSAGE  \
# 5842         0  http://news.bbc.co.uk/1/hi/england/2515127.stm...
# 5843         0  > >-- be careful when using this one.) Also, t...
# 5844         0  >>>>> "SM" == Skip Montanaro <skip@pobox.com> ...
# 5845         0  So then, "Mark Hammond" <mhammond@skippinet.co...
# 5846         0  Hi there,\n\n\n\nNow this is probably of no us...
#
#                                    FILE_NAME
# 5842  01396.61983fbe6ec43f55fd44e30fce24ffa6
# 5843  01397.9f9ef4c2a8dc012d80f2ce2d3473d3b7
# 5844  01398.169b51731fe569f42169ae8f948ec676
# 5845  01399.ca6b00b7b341bbde9a9ea3dd6a7bf896
# 5846  01400.f897f0931e461e7b2e964d28e927c35e

# %%
vectorizer = CountVectorizer(stop_words='english')

# %%
all_features = vectorizer.fit_transform(data.MESSAGE)

# %%
all_features.shape
# Out:
# (5847, 102277)

# %%
vectorizer.vocabulary_ # individual word present
# Out:
# {'doctype': 34757,
#  'html': 48296,
#  'public': 73722,
#  'w3c': 93388,
#  'dtd': 36243,
#  'transitional': 88204,
#  'en': 38314,
#  'head': 46845,
#  'meta': 61469,
#  'content': 30159,
#  '3d': 6370,
#  'text': 86628,
#  'charset': 27724,
#  '3dwindows': 7282,
#  '1252': 2023,
#  'http': 48321,
#  'equiv': 38871,
#  '3dcontent': 6893,
#  'ype': 98641,
#  'mshtml': 63171,
#  '00': 0,
#  '2314': 4227,
#  '1000': 1495,
#  '3dgenerator': 6972,
#  'body': 24336,
#  'inserted': 51935,
#  'calypso': 26491,
#  'table': 85768,
#  'border': 24524,
#  '3d0': 6371,
#  'cellpadding': 27303,
#  'cellspacing': 27311,
#  '3d2': 6510,
#  'id': 49648,
#  '3d_calyprintheader_': 6743,
#  'ules': 89863,
#  '3dnone': 7115,
#  'style': 84374,
#  'color': 29286,
#  'black': 23840,
#  'display': 34299,
#  'width': 95083,
#  '100': 1494,
#  'tbody': 86106,
#  'tr': 88067,
#  'td': 86192,
#  'colspan': 29309,
#  '3d3': 6555,
#  'hr': 48197,
#  '3dblack': 6848,
#  'noshade': 65596,
#  'size': 82015,
#  '3d1': 6402,
#  'end': 38378,
#  'font': 42116,
#  '000000': 4,
#  'face': 40374,
#  '3dverdana': 7268,
#  'arial': 20078,
#  'helvetica': 47053,
#  'br': 24756,
#  'ff0000': 41101,
#  'copperplate': 30359,
#  'gothic': 45145,
#  'bold': 24383,
#  '3d5': 6626,
#  'ptsize': 73685,
#  '10': 1493,
#  'center': 27333,
#  'save': 80051,
#  '70': 11046,
#  'life': 58235,
#  'insurance': 52064,
#  'ff': 41097,
#  '0000': 2,
#  'spend': 83243,
#  'pt': 73578,
#  'quote': 75319,
#  'savings': 80064,
#  'align': 18602,
#  '3dleft': 7048,
#  'bordercolor': 24527,
#  '111111': 1815,
#  'wi': 95051,
#  'dth': 36249,
#  '3d650': 6675,
#  '35': 5974,
#  '3d4': 6592,
#  'ensurin': 38573,
#  'family': 40525,
#  'financial': 41462,
#  'security': 80703,
#  'important': 51175,
#  'ma': 59924,
#  'kes': 55656,
#  'buying': 25555,
#  'simple': 81841,
#  'affordable': 17573,
#  'provide': 73370,
#  'free': 42630,
#  'access': 16632,
#  'best': 23078,
#  'companies': 29492,
#  'lowest': 59152,
#  'rates': 76053,
#  '3dmiddle': 7071,
#  'valign': 91648,
#  '3dtop': 7245,
#  '18': 2690,
#  'padding': 68882,
#  'left': 57745,
#  '5px': 9807,
#  'right': 78115,
#  'fast': 40607,
#  'eas': 37153,
#  'saves': 80059,
#  'money': 62602,
#  'let': 57876,
#  'help': 47033,
#  'started': 83793,
#  'val': 91623,
#  'ues': 89517,
#  'country': 30562,
#  'new': 64744,
#  'coverage': 30612,
#  'hundreds': 48428,
#  'tho': 87025,
#  'usands': 90895,
#  'dollars': 34837,
#  'requesting': 77409,
#  'lifequote': 58250,
#  'service': 81033,
#  'minutes': 62001,
#  'complete': 29582,
#  'shop': 81511,
#  'compare': 29508,
#  'types': 88995,
#  'height': 46990,
#  '3d50': 6627,
#  '3dcenter': 6877,
#  'href': 48214,
#  'website': 94645,
#  'e365': 36831,
#  'cc': 27034,
#  'savequote': 80056,
#  'click': 28642,
#  'strong': 84281,
#  'protecting': 73324,
#  'investment': 52419,
#  'll': 58680,
#  'eve': 39360,
#  'make': 60290,
#  'sans': 79940,
#  'serif': 80978,
#  'receipt': 76479,
#  'email': 38100,
#  'error': 38988,
#  'wish': 95282,
#  'removed': 77181,
#  'list': 58472,
#  'mailto': 60189,
#  'coins': 29187,
#  'btamail': 25189,
#  'net': 64624,
#  'cn': 28955,
#  'type': 88988,
#  'remove': 77166,
#  'reside': 77490,
#  'state': 83827,
#  'prohibits': 73155,
#  'mail': 60090,
#  'solicitations': 82799,
#  'insuran': 52063,
#  'ce': 27222,
#  'disregard': 34326,
#  'fight': 41369,
#  'risk': 78189,
#  'cancer': 26554,
#  'www': 96120,
#  'adclick': 17031,
#  'ws': 95889,
#  'cfm': 27456,
#  '315': 5710,
#  'pk007': 71553,
#  'slim': 82286,
#  'guaranteed': 45713,
#  'lose': 59080,
#  '12': 1953,
#  'lbs': 57528,
#  '30': 5580,
#  'days': 32320,
#  '249': 4387,
#  'child': 27899,
#  'support': 84828,
#  'deserve': 33251,
#  'legal': 57759,
#  'advice': 17330,
#  '245': 4369,
#  'pk002': 71552,
#  'join': 54473,
#  'web': 94560,
#  'fastest': 40614,
#  'growing': 45567,
#  'singles': 81905,
#  'community': 29477,
#  '259': 4500,
#  'start': 83791,
#  'private': 72940,
#  'photo': 71063,
#  'album': 18530,
#  'online': 67406,
#  '283': 4713,
#  'wonderful': 95565,
#  'day': 32309,
#  'offer': 66900,
#  'manager': 60379,
#  'prizemama': 72960,
#  'leave': 57708,
#  'use': 90921,
#  'link': 58393,
#  'qves': 75353,
#  'com': 29323,
#  'trim': 88391,
#  'ilug': 50945,
#  'linux': 58423,
#  '7c17': 11602,
#  '7c114258': 11600,
#  'irish': 52732,
#  'users': 90972,
#  'group': 45553,
#  'mailman': 60171,
#  'listinfo': 58516,
#  'subscription': 84495,
#  'information': 51693,
#  'maintainer': 60264,
#  'listmaster': 58521,
#  'zzzz': 101010,
#  'spamassassin': 83064,
#  'taint': 85854,
#  'org': 67807,
#  '7c308417': 11606,
#  'adult': 17275,
#  'club': 28779,
#  'offers': 66910,
#  'membership': 61308,
#  'instant': 52013,
#  'sites': 81973,
#  'user': 90942,
#  'password': 69308,
#  '760382': 11359,
#  'internet': 52218,
#  'news': 64789,
#  '08': 768,
#  '02': 396,
#  'just': 54854,
#  'million': 61881,
#  'members': 61307,
#  'signed': 81756,
#  'month': 62670,
#  '721': 11168,
#  '184': 2728,
#  'faq': 40559,
#  'offering': 66908,
#  'advertisers': 17319,
#  'pay': 69419,
#  'ad': 16947,
#  'space': 83023,
#  'don': 34884,
#  'true': 88495,
#  'absolutely': 16471,
#  'cent': 27329,
#  'account': 16688,
#  'friends': 42790,
#  'yes': 98141,
#  'long': 58998,
#  'age': 17721,
#  'sign': 81739,
#  'following': 42092,
#  'links': 58408,
#  'member': 61305,
#  'multi': 63388,
#  'dollar': 34836,
#  'operations': 67575,
#  'policies': 72066,
#  'rules': 79108,
#  'required': 77412,
#  'info': 51655,
#  'won': 95562,
#  'charge': 27704,
#  'pass': 69275,
#  'believe': 22934,
#  'read': 76312,
#  'terms': 86534,
#  'conditions': 29762,
#  'adults': 17278,
#  'farm': 40577,
#  '80': 12003,
#  '71': 11111,
#  '66': 10327,
#  'aid': 18092,
#  'girls': 44565,
#  'animals': 19252,
#  'getting': 44285,
#  'freaky': 42620,
#  'lifetime': 58256,
#  'sexy': 81135,
#  'celebes': 27271,
#  'celebst': 27285,
#  'thousands': 87056,
#  'xxx': 97470,
#  'doing': 34819,
#  'play': 71701,
#  'house': 48086,
#  'porn': 72217,
#  'mega': 61239,
#  'live': 58563,
#  'feeds': 40968,
#  '60': 10022,
#  'cams': 26535,
#  'asian': 20349,
#  'sex': 81117,
#  'fantasies': 40547,
#  'japanese': 53664,
#  'schoolgirls': 80289,
#  'shows': 81591,
#  'lesbian': 57857,
#  'lace': 57188,
#  'jennifer': 53919,
#  'simpson': 81854,
#  'miami': 61701,
#  'fl': 41699,
#  'entertained': 38595,
#  'boyffriend': 24660,
#  'years': 98093,
#  'joe': 54428,
#  'morgan': 62742,
#  'manhattan': 60419,
#  'ny': 66174,
#  'unbelievable': 90047,
#  'removal': 77160,
#  'instructions': 52039,
#  'received': 76485,
#  'advertisement': 17316,
#  'opted': 67640,
#  'receive': 76484,
#  'specials': 83177,
#  'affiliated': 17553,
#  'websites': 94647,
#  'emails': 38132,
#  'opt': 67636,
#  'database': 32220,
#  'optout': 67691,
#  'allow': 18690,
#  '24': 4340,
#  'hours': 48085,
#  'vonolmosatkirekpups': 92830,
#  'thought': 87050,
#  'like': 58294,
#  'freeyankee': 42720,
#  'cgi': 27541,
#  'fy2': 43331,
#  '822slim1': 12180,
#  '822nic1': 12178,
#  '822ppl1': 12179,
#  'daily': 32075,
#  'deals': 32609,
#  'social': 82697,
#  '7c29': 11603,
#  '7c134077': 11601,
#  'events': 39369,
#  'powerhouse': 72424,
#  'gifting': 44504,
#  'program': 73119,
#  'want': 93755,
#  'miss': 62083,
#  'founders': 42400,
#  'major': 60282,
#  'players': 71707,
#  'invitation': 52430,
#  'experts': 39806,
#  'calling': 26466,
#  'way': 93931,
#  'huge': 48366,
#  'cash': 26825,
#  'flow': 41888,
#  'conceived': 29699,
#  'leverage': 57921,
#  '000': 1,
#  '50': 8910,
#  'question': 75233,
#  'wealthy': 94548,
#  'tossing': 87883,
#  'lifeline': 58247,
#  'sake': 79801,
#  'hope': 47961,
#  'grab': 45279,
#  'hold': 47796,
#  'tight': 87220,
#  'ride': 78086,
#  'testimonials': 86596,
#  'hear': 46911,
#  'average': 21028,
#  'people': 70173,
#  've': 91883,
#  'al': 18466,
#  'single': 81902,
#  'mother': 62820,
#  'sure': 84860,
#  'sent': 80898,
#  'pledge': 71746,
#  'got': 45137,
#  'ky': 56814,
#  'didn': 33857,
#  'partner': 69258,
#  'work': 95623,
#  'think': 86964,
#  'decision': 32712,
#  'pick': 71222,
#  'gave': 43854,
#  'leads': 57673,
#  'training': 88148,
#  'ca': 26301,
#  'announcing': 19323,
#  'close': 28741,
#  'sales': 79818,
#  'fax': 40678,
#  'blast': 23889,
#  'immediately': 51072,
#  'entry': 38648,
#  'wait': 93655,
#  '800': 12004,
#  '421': 7986,
#  '6318': 10168,
#  '896': 12850,
#  '6568': 10300,
#  'name__________________________________phone___________________________________________': 64120,
#  'fax_____________________________________email____________________________________________': 40680,
#  'time': 87259,
#  'call_________________________time': 26454,
#  'zone________________________________________': 100278,
#  'message': 61448,
#  'compliance': 29596,
#  'section': 80675,
#  '301': 5594,
#  'paragraph': 69112,
#  '1618': 2475,
#  'transmissions': 88227,
#  'sender': 80860,
#  'stopped': 84107,
#  'cost': 30485,
#  'sending': 80868,
#  'reply': 77318,
#  'address': 17068,
#  'word': 95607,
#  'subject': 84440,
#  'line': 58360,
#  'errors': 38989,
#  'omissions': 67314,
#  'exceptions': 39565,
#  'excluded': 39598,
#  'spam': 83050,
#  'compiled': 29560,
#  'replicate': 77314,
#  'relative': 77009,
#  'seattle': 80630,
#  'marketing': 60572,
#  'gigt': 44520,
#  'turbo': 88733,
#  'team': 86242,
#  'sole': 82790,
#  'purpose': 73855,
#  'communications': 29467,
#  'continued': 30189,
#  'inclusion': 51353,
#  'gracious': 45288,
#  'permission': 70283,
#  'send': 80853,
#  'tesrewinter': 86575,
#  'yahoo': 97891,
#  'deleted': 32958,
#  'wanted': 93756,
#  '14': 2222,
#  'year': 98086,
#  'old': 67202,
#  'fortune': 42357,
#  '500': 8911,
#  'company': 29495,
#  'tremendous': 88335,
#  'rate': 76050,
#  'looking': 59019,
#  'individuals': 51542,
#  'home': 47834,
#  'opportunity': 67612,
#  'excellent': 39557,
#  'income': 51359,
#  'experience': 39789,
#  'train': 88144,
#  'employed': 38256,
#  'career': 26716,
#  'vast': 91737,
#  'opportunities': 67611,
#  'basetel': 22451,
#  'wealthnow': 94545,
#  'energetic': 38431,
#  'self': 80801,
#  'motivated': 62832,
#  'form': 42283,
#  'employement': 38260,
#  'specialist': 83167,
#  'contact': 30108,
#  '4139volw7': 7943,
#  '758dody1425frhm1': 11335,
#  '764smfc8513fcsll40': 11370,
#  'title': 87359,
#  'reliaquote': 77056,
#  'iso': 52906,
#  '8859': 12811,
#  'leftmargin': 57750,
#  'topmargin': 87834,
#  'ffcc99': 41151,
#  'vlink': 92666,
#  'alink': 18610,
#  'ffcc00': 41148,
#  '468': 8213,
#  'bgcolor': 23245,
#  '993366': 13970,
#  '43': 8031,
#  '56': 9270,
#  'theadmanager': 86826,
#  'server': 81018,
#  'asp': 20390,
#  'ad_key': 16984,
#  'yuesbhwakmlk': 98817,
#  'ext': 39897,
#  'target': 85993,
#  '_blank': 14776,
#  'img': 51031,
#  'src': 83529,
#  'banner': 22332,
#  'bannerads': 22336,
#  'images': 50985,
#  'logo6': 58959,
#  'gif': 44493,
#  '120': 1954,
#  '32': 5742,
#  '44': 8080,
#  'nbsp': 64318,
#  '377': 6111,
#  'ffccff': 41153,
#  'headline6': 46878,
#  '220': 3990,
#  '72': 11162,
#  '336699': 5870,
#  '34': 5908,
#  '45': 8134,
#  'tahoma': 85838,
#  'verdana': 92016,
#  'change': 27646,
#  'protect': 73322,
#  'future': 43187,
#  'sufficient': 84626,
#  'middle': 61788,
#  '27': 4610,
#  'freequotes6': 42686,
#  '177': 2650,
#  '3366cc': 5871,
#  '294': 4800,
#  'freequoteform': 42685,
#  'action': 16872,
#  'termlife': 86530,
#  'bin': 23574,
#  'banner_quote_resp': 22335,
#  'method': 61505,
#  'input': 51888,
#  'hidden': 47338,
#  'value': 91662,
#  '51100004022000000321': 9009,
#  'sourceid': 82970,
#  'class': 28530,
#  'hptbcolor': 48159,
#  'ffffff': 41189,
#  'residence': 77491,
#  '65': 10269,
#  'select': 80782,
#  'formscombobox12': 42314,
#  'option': 67677,
#  'selected': 80789,
#  'alabama': 18487,
#  'alaska': 18505,
#  'arizona': 20095,
#  'arkansas': 20100,
#  'california': 26449,
#  'colorado': 29288,
#  'connecticut': 29932,
#  'delaware': 32945,
#  'dc': 32391,
#  'dist': 34354,
#  'columbia': 29313,
#  'florida': 41877,
#  'georgia': 44200,
#  'hawaii': 46672,
#  'idaho': 49781,
#  'illinois': 50915,
#  'indiana': 51494,
#  'iowa': 52514,
#  'kansas': 55350,
#  'kentucky': 55622,
#  'louisiana': 59117,
#  'maine': 60252,
#  'maryland': 60649,
#  'massachusetts': 60672,
#  'michigan': 61723,
#  'minnesota': 61986,
#  'mississippi': 62098,
#  'missouri': 62102,
#  'montana': 62663,
#  'nebraska': 64470,
#  'nevada': 64738,
#  'hampshire': 46401,
#  'jersey': 53939,
#  'mexico': 61533,
#  'york': 98570,
#  'north': 65564,
#  'carolina': 26765,
#  'dakota': 32090,
#  'ohio': 67037,
#  'oklahoma': 67173,
#  'oregon': 67798,
#  'pennsylvania': 70154,
#  'rhode': 78009,
#  'island': 52886,
#  'south': 82978,
#  'tennessee': 86484,
#  'texas': 86625,
#  'utah': 91050,
#  'vermont': 92049,
#  'virginia': 92454,
#  'washington': 93860,
#  'west': 94782,
#  'wisconsin': 95276,
#  'wyoming': 96207,
#  'date': 32243,
#  'birth': 23648,
#  'mm': 62323,
#  'dd': 32513,
#  'yy': 99125,
#  'nowrap': 65690,
#  '01': 309,
#  '03': 488,
#  '04': 550,
#  '05': 599,
#  '06': 655,
#  '07': 706,
#  '09': 842,
#  '11': 1796,
#  '13': 2105,
#  '15': 2337,
#  '16': 2460,
#  '17': 2581,
#  '19': 2796,
#  '20': 3481,
#  '21': 3886,
#  '22': 3989,
#  '23': 4206,
#  '25': 4424,
#  '26': 4527,
#  '28': 4699,
#  '29': 4782,
#  '31': 5675,
#  '33': 5818,
#  '36': 6023,
#  '37': 6079,
#  '38': 6128,
#  '39': 6168,
#  '40': 7809,
#  '41': 7924,
#  '42': 7982,
#  '46': 8189,
#  '47': 8231,
#  '48': 8279,
#  '49': 8328,
#  '51': 9002,
#  '52': 9056,
#  '53': 9102,
#  '54': 9169,
#  '55': 9220,
#  '57': 9324,
#  '58': 9356,
#  '59': 9396,
#  '61': 10076,
#  '62': 10124,
#  '63': 10163,
#  '64': 10214,
#  '67': 10415,
#  '68': 10452,
#  '69': 10488,
#  '73': 11198,
#  '74': 11244,
#  '75': 11300,
#  '76': 11357,
#  '77': 11394,
#  '78': 11443,
#  '79': 11483,
#  '81': 12097,
#  '82': 12161,
#  '83': 12242,
#  '84': 12335,
#  'formsradiobutton1': 42315,
#  'radio': 75829,
#  'male': 60321,
#  'formsradiobutton2': 42316,
#  'female': 41017,
#  'used': 90928,
#  'tobacco': 87656,
#  'products': 73060,
#  'months': 62678,
#  'formsradiobutton4': 42318,
#  'formsradiobutton3': 42317,
#  'formscombobox11': 42313,
#  '100000': 1497,
#  '125000': 2021,
#  '125': 2019,
#  '150000': 2341,
#  '150': 2338,
#  '175000': 2632,
#  '175': 2630,
#  '200000': 3485,
#  '200': 3482,
#  '225000': 4077,
#  '225': 4074,
#  '250000': 4427,
#  '250': 4425,
#  '275000': 4653,
#  '275': 4651,
#  '300000': 5583,
#  '300': 5581,
#  '325000': 5776,
#  '325': 5774,
#  '350000': 5977,
#  '350': 5975,
#  '375000': 6106,
#  '375': 6105,
#  '400000': 7812,
#  '400': 7810,
#  '425000': 8003,
#  '425': 8002,
#  '450000': 8137,
#  '450': 8135,
#  '475000': 8250,
#  '475': 8249,
#  '500000': 8914,
#  '550000': 9223,
#  '550': 9221,
#  '600000': 10026,
#  '600': 10023,
#  '650000': 10272,
#  '650': 10270,
#  '700000': 11049,
#  '700': 11047,
#  '750000': 11303,
#  '750': 11301,
#  '800000': 12007,
#  '850000': 12442,
#  '850': 12440,
#  '900000': 13564,
#  '900': 13562,
#  '950000': 13772,
#  '950': 13770,
#  '1000000': 1498,
#  '1250000': 2022,
#  '1500000': 2342,
#  '1750000': 2633,
#  '2000000': 3486,
#  '2250000': 4078,
#  '2500000': 4428,
#  '3000000': 5584,
#  '3500000': 5978,
#  '4000000': 7813,
#  '4500000': 8138,
#  '5000000': 8915,
#  '6000000': 10027,
#  '7000000': 11050,
#  '8000000': 12008,
#  '9000000': 13565,
#  '10000000': 1499,
#  '11000000': 1799,
#  '12000000': 1957,
#  '13000000': 2109,
#  '14000000': 2226,
#  '15000000': 2343,
#  'need': 64496,
#  'formscombobox10': 42312,
#  'plan': 71646,
#  'formsbutton1': 42311,
#  'submit': 84463,
#  'submitbutton': 84465,
#  'photo6': 71072,
#  'jpg': 54587,
#  '210': 3887,
#  '173': 2614,
#  '217': 3954,
#  'div': 34422,
#  'makes': 60305,
#  'easy': 37175,
#  'instantly': 52017,
#  'quotes': 75323,
#  'highly': 47368,
#  'rated': 76051,
#  '106': 1716,
#  '70percent6': 11107,
#  '131': 2118,
#  'ffcc33': 41149,
#  'today': 87670,
#  '0000ff': 53,
#  'copyright': 30372,
#  '2001': 3496,
#  'rights': 78126,
#  'reserved': 77480,
#  'admanmail': 17161,
#  'hspace': 48261,
#  'vspace': 93032,
#  'alt': 18771,
#  'receiving': 76495,
#  'mailing': 60159,
#  'sendgreatoffers': 80865,
#  'subscribed': 84489,
#  'jm': 54260,
#  'netnoteinc': 64677,
#  'unsubscribe': 90564,
#  'em': 38072,
#  'sgo': 81217,
#  'include': 51346,
#  'unsubscribed': 90568,
#  'correspondence': 30449,
#  'services': 81035,
#  'directed': 34052,
#  'tired': 87343,
#  'bull': 25366,
#  'stop': 84082,
#  'losing': 59087,
#  'real': 76344,
#  'maker': 60302,
#  'big': 23493,
#  'boys': 24667,
#  'drive': 36102,
#  'doorstep': 34937,
#  'short': 81525,
#  'period': 70237,
#  'print': 72895,
#  'successleads': 84571,
#  'firemail': 41537,
#  'telephone': 86395,
#  'number': 65992,
#  'responding': 77565,
#  '499': 8356,
#  '99': 13952,
#  'name___________________________________': 64113,
#  'phone___________________________________': 71044,
#  'fax_____________________________________': 40679,
#  'email___________________________________': 38109,
#  'dear': 32617,
#  'ricardo1': 78056,
#  'red': 76638,
#  'effective': 37585,
#  'direct': 34049,
#  'advertising': 17321,
#  'blue': 24052,
#  'promote': 73196,
#  'business': 25490,
#  'low': 59143,
#  'addresses': 17086,
#  '44c300': 8122,
#  'maximize': 60798,
#  '309': 5631,
#  '407': 7873,
#  '7378': 11226,
#  'consultant': 30079,
#  'discuss': 34207,
#  'needs': 64506,
#  '___________________________________________________________________': 14698,
#  '_______________________________________________________________': 14694,
#  '________________________________________________________________': 14695,
#  'city': 28306,
#  '_____________________________________________________________________': 14700,
#  'phone': 71040,
#  '__________________________________________________________________': 14697,
#  '_______________________________________________________': 14686,
#  '___________________________________________________________________________': 14704,
#  'comments': 29411,
#  'details': 33338,
#  'pricing': 72859,
#  'market': 60565,
#  '247': 4378,
#  'po1': 71978,
#  'kj': 56023,
#  '_8j7bjk9': 14634,
#  'tg0bk5nkiys5': 86726,
#  'cellular': 27312,
#  'accessories': 16643,
#  'wholesale': 95016,
#  'prices': 72855,
#  '202': 3680,
#  '101': 1547,
#  '163': 2492,
#  'merchant': 61395,
#  'hands': 46439,
#  'ear': 37126,
#  'buds': 25288,
#  'holsters': 47827,
#  '98': 13896,
#  'booster': 24488,
#  'antennas': 19398,
#  'cases': 26823,
#  'car': 26673,
#  'chargers': 27707,
#  'plates': 71685,
#  'lithium': 58544,
#  'ion': 52491,
#  'batteries': 22512,
#  '94': 13731,
#  'nokia': 65446,
#  'motorola': 62850,
#  'lg': 57999,
#  'nextel': 64854,
#  'samsung': 79886,
#  'qualcomm': 75151,
#  'ericsson': 38938,
#  'audiovox': 20795,
#  'phones': 71052,
#  'assistance': 20464,
#  '732': 11205,
#  '751': 11313,
#  '1457': 2279,
#  'mailings': 60163,
#  'request': 77406,
#  'removemenow68994': 77190,
#  'thank': 86799,
#  'super': 84755,
#  'free4pornlovers': 42635,
#  'simply': 81852,
#  'amateur': 18863,
#  '990000': 13955,
#  '660066': 10330,
#  '9933ff': 13971,
#  'girl': 44562,
#  'door': 34933,
#  'tour': 87925,
#  'ff0099': 41106,
#  'photos': 71090,
#  'sneeky': 82593,
#  'nude': 65961,
#  'exibitionists': 39692,
#  'cheating': 27775,
#  'wives': 95320,
#  'girlfriends': 44564,
#  'pl': 71617,
#  'cell': 27292,
#  'spacer': 83028,
#  '185': 2734,
#  'rowspan': 78742,
#  'qbfuiexorxkl': 74424,
#  '168': 2535,
#  '143': 2259,
#  '181': 2706,
#  'htmlemails': 48306,
#  't193no_option_01': 85482,
#  't193no_option_02': 85483,
#  't193no_option_03': 85484,
#  't193no_option_04': 85485,
#  't193no_option_05': 85486,
#  't193no_option_06': 85487,
#  '115': 1855,
#  't193no_option_07': 85488,
#  '154': 2393,
#  't193no_option_08': 85489,
#  't193no_option_09': 85490,
#  't193no_option_10': 85491,
#  't193no_option_11': 85492,
#  't193no_option_12': 85493,
#  't193no_option_13': 85494,
#  't193no_option_14': 85495,
#  '265': 4554,
#  'simplywireless': 81853,
#  'swdotcomlogo1': 85068,
#  '273': 4637,
#  'voicestream': 92790,
#  'wireless': 95262,
#  'credit': 30881,
#  'approval': 19794,
#  'activate': 16882,
#  'activation': 16885,
#  'fee': 40962,
#  'applies': 19745,
#  'activations': 16886,
#  'available': 21005,
#  'areas': 20037,
#  'fulfilled': 43087,
#  'authorized': 20889,
#  'dealer': 32604,
#  'site': 81952,
#  ...}

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, data.CATEGORY)

# %%
X_train.shape
# Out:
# (4385, 102277)

# %%
X_test.shape
# Out:
# (1462, 102277)

# %%
classifier = MultinomialNB() # model

# %%
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
nr_correct = (y_test == classifier.predict(X_test)).sum()

# %%
print(f'{nr_correct} documents classfied correctly')
# Out:
# 1391 documents classfied correctly

# %%
nr_incorrect = y_test.size - nr_correct

# %%
print(f'Number of documents incorrectly classified is {nr_incorrect}')
# Out:
# Number of documents incorrectly classified is 71

# %%
fraction_wrong = nr_incorrect / (nr_correct + nr_incorrect)
print(f'The (testing) accuracy of the model is {1-fraction_wrong:.2%}')
# Out:
# The (testing) accuracy of the model is 95.14%

# %%
classifier.score(X_test, y_test)
# Out:
# 0.9514363885088919

# %%
recall_score(y_test, classifier.predict(X_test))
# Out:
# 0.8574468085106383

# %%
precision_score(y_test, classifier.predict(X_test))
# Out:
# 0.9901719901719902

# %%
f1_score(y_test, classifier.predict(X_test))
# Out:
# 0.9190421892816419

# %%
examples = ['i cant pick the call right now, please send a message',
         'congratulations youre awarded $500',
         'need a mortgage? Reply to arrange a call with a specialist and get a quote',
         'We are going to implement two techniques',
         'Confirm once youve registered',
         'want bitcoin for free? register now link below']

# %%
mail_class = vectorizer.transform(examples)

# %%
classifier.predict(mail_class)
# Out:
# array([0, 1, 1, 0, 0, 1], dtype=int64)
